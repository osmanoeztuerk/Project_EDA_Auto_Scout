# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">Osman Öztürk</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
from scipy.stats.mstats import winsorize

import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10, 6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 150

# %%
# function for first looking to the columns

def first_looking(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print("--------------------------------")
    print(df[col].value_counts(dropna = False))

# %% [markdown]
# ## functions to fill the missing values

# %%
def fill_most(df, group_col, col_name):
    '''Fills the missing values with the most existing value (mode) in the relevant column according to single-stage grouping'''
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])
    print("Number of NaN : ", df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
def fill_prop(df, group_col, col_name):
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    print("Number of NaN : ", df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
def fill(df, group_col1, group_col2, col_name, method): # method can be either "mode" or "mean" or "median" or "ffill"
    
    '''Fills the missing values with "mode/mean/median/ffill/bfill method" according to double-stage grouping'''
    
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

    elif method == "mean":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df[col_name].mean(), inplace = True)
        
    elif method == "median":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df[col_name].median(), inplace = True)
        
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
df = pd.read_csv("filled_scout.csv")

# %%
df.shape
# Out:
# (15919, 25)

# %%
df.head(3).T
# Out:
#                                                                             0  \
# make_model                                                            Audi A1
# body_type                                                              Sedans
# price                                                                   15770
# km                                                                  56013.000
# Type                                                                     Used
# Fuel                                                                   Diesel
# Gears                                                                   7.000
# Extras                       Alloy wheels, Catalytic Converter, Voice Control
# age                                                                     3.000
# Previous_Owners                                                         2.000
# hp_kW                                                                  66.000
# Inspection_new                                                              1
# Paint_Type                                                           Metallic
# Upholstery_type                                                         Cloth
# Nr_of_Doors                                                             5.000
# Nr_of_Seats                                                             5.000
# Gearing_Type                                                        Automatic
# Displacement_cc                                                      1422.000
# Weight_kg                                                            1220.000
# Drive_chain                                                             front
# cons_comb                                                               3.800
# CO2_Emission                                                           99.000
# Comfort_Convenience_Package                                           Premium
# Entertainment_Media_Package                                              Plus
# Safety_Security_Package                                Safety Premium Package
#
#                                                                              1  \
# make_model                                                             Audi A1
# body_type                                                               Sedans
# price                                                                    14500
# km                                                                   80000.000
# Type                                                                      Used
# Fuel                                                                   Benzine
# Gears                                                                    7.000
# Extras                       Alloy wheels, Sport seats, Sport suspension, V...
# age                                                                      2.000
# Previous_Owners                                                          1.000
# hp_kW                                                                  141.000
# Inspection_new                                                               0
# Paint_Type                                                            Metallic
# Upholstery_type                                                          Cloth
# Nr_of_Doors                                                              3.000
# Nr_of_Seats                                                              4.000
# Gearing_Type                                                         Automatic
# Displacement_cc                                                       1798.000
# Weight_kg                                                             1255.000
# Drive_chain                                                              front
# cons_comb                                                                5.600
# CO2_Emission                                                           129.000
# Comfort_Convenience_Package                                           Standard
# Entertainment_Media_Package                                               Plus
# Safety_Security_Package                                 Safety Premium Package
#
#                                                        2
# make_model                                       Audi A1
# body_type                                         Sedans
# price                                              14640
# km                                             83450.000
# Type                                                Used
# Fuel                                              Diesel
# Gears                                              7.000
# Extras                       Alloy wheels, Voice Control
# age                                                3.000
# Previous_Owners                                    1.000
# hp_kW                                             85.000
# Inspection_new                                         0
# Paint_Type                                      Metallic
# Upholstery_type                                    Cloth
# Nr_of_Doors                                        4.000
# Nr_of_Seats                                        4.000
# Gearing_Type                                   Automatic
# Displacement_cc                                 1598.000
# Weight_kg                                       1135.000
# Drive_chain                                        front
# cons_comb                                          3.800
# CO2_Emission                                      99.000
# Comfort_Convenience_Package                      Premium
# Entertainment_Media_Package                     Standard
# Safety_Security_Package           Safety Premium Package

# %% [markdown]
# # The Examination of OUTLIERS in the Columns

# %% [markdown]
# ## km

# %%
first_looking("km")
# Out:
# column name    :  km
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6692
# --------------------------------
# 10.000       1045
# 1647.363      985
# 1.000         367
# 5.000         170
# 50.000        148
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6692, dtype: int64

# %%
plt.figure(figsize=(18, 6))

plt.subplot(141)
plt.hist(df.km, bins=50)

plt.subplot(142)
plt.boxplot(df.km)

plt.subplot(143)
plt.boxplot(df.km, whis=2.5)

plt.subplot(144)
plt.boxplot(np.log(df.km), whis=2.5)

plt.show()

# %%
#df["km_logged"] = np.log(df.km)

# %% [markdown]
# **``km``** **is a variable with a wide range of values. We CANNOT consider the extreme values above as  genuine outliers. So let's keep these extreme values as they are.**

# %% [markdown]
# ## Gears

# %%
first_looking("Gears")
# Out:
# column name    :  Gears
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  10
# --------------------------------
# 6.000     8615
# 5.000     4255
# 7.000     2810
# 8.000      225
# 9.000        6
# 1.000        2
# 3.000        2
# 4.000        2
# 2.000        1
# 50.000       1
# Name: Gears, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.Gears, bins=50)

plt.subplot(122)
plt.boxplot(df.Gears, whis=2.5)

plt.show()

# %%
df.Gears.describe()
# Out:
# count   15919.000
# mean        5.940
# std         0.792
# min         1.000
# 25%         5.000
# 50%         6.000
# 75%         6.000
# max        50.000
# Name: Gears, dtype: float64

# %%
df.sort_values(by=["Gears"], ascending=False)["Gears"].head(10)
# Out:
# 14495   50.000
# 15827    9.000
# 15824    9.000
# 15814    9.000
# 15869    9.000
# 15812    9.000
# 15876    9.000
# 12463    8.000
# 12470    8.000
# 12469    8.000
# Name: Gears, dtype: float64

# %%
df.sort_values(by=["Gears"], ascending=True)["Gears"].head(10)
# Out:
# 8921    1.000
# 14375   1.000
# 9812    2.000
# 15817   3.000
# 15845   3.000
# 15823   4.000
# 15822   4.000
# 10427   5.000
# 10428   5.000
# 10429   5.000
# Name: Gears, dtype: float64

# %%
# Let's check the observations having extreme Gear value.

df[(df.Gears < 5) | (df.Gears > 8)][["make_model", "body_type", "Gearing_Type", "Gears"]]
# Out:
#            make_model body_type    Gearing_Type  Gears
# 8921       Opel Corsa   Compact  Semi-automatic  1.000
# 9812       Opel Corsa    Sedans          Manual  2.000
# 14375    Renault Clio   Compact       Automatic  1.000
# 14495    Renault Clio    Sedans          Manual 50.000
# 15812  Renault Espace       Van       Automatic  9.000
# 15814  Renault Espace       Van       Automatic  9.000
# 15817  Renault Espace       Van       Automatic  3.000
# 15822  Renault Espace       Van       Automatic  4.000
# 15823  Renault Espace       Van       Automatic  4.000
# 15824  Renault Espace       Van       Automatic  9.000
# 15827  Renault Espace       Van       Automatic  9.000
# 15845  Renault Espace       Van       Automatic  3.000
# 15869  Renault Espace       Van       Automatic  9.000
# 15876  Renault Espace       Van       Automatic  9.000

# %%
# Let's check the observations belongs to "Renault Espace" model to see distribution of Gear values. 

df[(df.make_model == "Renault Espace")][["make_model", "body_type", "Gearing_Type", "Gears"]]
# Out:
#            make_model      body_type    Gearing_Type  Gears
# 14928  Renault Espace            Van       Automatic  6.000
# 14929  Renault Espace  Station wagon       Automatic  6.000
# 14930  Renault Espace    Transporter       Automatic  6.000
# 14931  Renault Espace            Van       Automatic  6.000
# 14932  Renault Espace            Van       Automatic  6.000
# 14933  Renault Espace    Transporter       Automatic  6.000
# 14934  Renault Espace            Van       Automatic  6.000
# 14935  Renault Espace            Van       Automatic  6.000
# 14936  Renault Espace       Off-Road       Automatic  6.000
# 14937  Renault Espace            Van       Automatic  6.000
# 14938  Renault Espace            Van       Automatic  6.000
# 14939  Renault Espace    Transporter       Automatic  6.000
# 14940  Renault Espace            Van       Automatic  6.000
# 14941  Renault Espace            Van       Automatic  6.000
# 14942  Renault Espace            Van       Automatic  6.000
# 15132  Renault Espace            Van       Automatic  6.000
# 15133  Renault Espace    Transporter       Automatic  7.000
# 15134  Renault Espace        Compact       Automatic  6.000
# 15135  Renault Espace            Van       Automatic  6.000
# 15136  Renault Espace    Transporter       Automatic  7.000
# 15137  Renault Espace            Van       Automatic  6.000
# 15138  Renault Espace            Van       Automatic  6.000
# 15139  Renault Espace            Van       Automatic  6.000
# 15140  Renault Espace            Van       Automatic  6.000
# 15141  Renault Espace            Van       Automatic  6.000
# 15142  Renault Espace            Van       Automatic  6.000
# 15143  Renault Espace            Van       Automatic  7.000
# 15144  Renault Espace            Van       Automatic  6.000
# 15145  Renault Espace  Station wagon       Automatic  6.000
# 15146  Renault Espace  Station wagon       Automatic  6.000
# 15147  Renault Espace            Van       Automatic  6.000
# 15148  Renault Espace            Van       Automatic  7.000
# 15149  Renault Espace  Station wagon       Automatic  6.000
# 15150  Renault Espace            Van       Automatic  6.000
# 15151  Renault Espace            Van       Automatic  6.000
# 15152  Renault Espace            Van       Automatic  6.000
# 15153  Renault Espace            Van       Automatic  6.000
# 15154  Renault Espace            Van       Automatic  6.000
# 15155  Renault Espace         Sedans       Automatic  6.000
# 15156  Renault Espace         Sedans       Automatic  6.000
# 15157  Renault Espace            Van       Automatic  6.000
# 15158  Renault Espace            Van       Automatic  6.000
# 15159  Renault Espace            Van       Automatic  6.000
# 15160  Renault Espace            Van       Automatic  6.000
# 15161  Renault Espace            Van       Automatic  6.000
# 15162  Renault Espace            Van       Automatic  6.000
# 15163  Renault Espace            Van       Automatic  6.000
# 15164  Renault Espace            Van       Automatic  6.000
# 15165  Renault Espace            Van       Automatic  6.000
# 15166  Renault Espace  Station wagon       Automatic  6.000
# 15167  Renault Espace  Station wagon       Automatic  6.000
# 15168  Renault Espace            Van       Automatic  6.000
# 15169  Renault Espace  Station wagon       Automatic  6.000
# 15170  Renault Espace    Transporter       Automatic  7.000
# 15171  Renault Espace            Van       Automatic  6.000
# 15172  Renault Espace    Transporter       Automatic  6.000
# 15173  Renault Espace  Station wagon       Automatic  6.000
# 15174  Renault Espace            Van       Automatic  6.000
# 15175  Renault Espace            Van       Automatic  6.000
# 15176  Renault Espace  Station wagon       Automatic  6.000
# 15177  Renault Espace            Van       Automatic  6.000
# 15178  Renault Espace            Van       Automatic  7.000
# 15179  Renault Espace            Van       Automatic  6.000
# 15180  Renault Espace            Van       Automatic  6.000
# 15181  Renault Espace            Van       Automatic  6.000
# 15182  Renault Espace            Van       Automatic  6.000
# 15183  Renault Espace  Station wagon       Automatic  6.000
# 15184  Renault Espace            Van       Automatic  6.000
# 15185  Renault Espace            Van       Automatic  6.000
# 15186  Renault Espace            Van       Automatic  6.000
# 15187  Renault Espace    Transporter       Automatic  6.000
# 15188  Renault Espace            Van       Automatic  6.000
# 15189  Renault Espace  Station wagon       Automatic  6.000
# 15190  Renault Espace            Van       Automatic  6.000
# 15191  Renault Espace            Van       Automatic  6.000
# 15192  Renault Espace            Van       Automatic  6.000
# 15193  Renault Espace            Van       Automatic  6.000
# 15194  Renault Espace            Van       Automatic  6.000
# 15195  Renault Espace            Van       Automatic  6.000
# 15196  Renault Espace        Compact       Automatic  6.000
# 15197  Renault Espace            Van       Automatic  6.000
# 15198  Renault Espace            Van       Automatic  6.000
# 15199  Renault Espace            Van       Automatic  6.000
# 15200  Renault Espace            Van       Automatic  6.000
# 15201  Renault Espace            Van       Automatic  6.000
# 15202  Renault Espace            Van       Automatic  6.000
# 15203  Renault Espace            Van       Automatic  6.000
# 15204  Renault Espace  Station wagon       Automatic  7.000
# 15205  Renault Espace            Van       Automatic  6.000
# 15206  Renault Espace            Van       Automatic  6.000
# 15207  Renault Espace            Van       Automatic  6.000
# 15208  Renault Espace            Van       Automatic  6.000
# 15209  Renault Espace            Van       Automatic  6.000
# 15210  Renault Espace            Van       Automatic  6.000
# 15211  Renault Espace            Van       Automatic  6.000
# 15212  Renault Espace  Station wagon       Automatic  6.000
# 15213  Renault Espace            Van       Automatic  6.000
# 15214  Renault Espace            Van       Automatic  7.000
# 15215  Renault Espace  Station wagon       Automatic  6.000
# 15216  Renault Espace  Station wagon       Automatic  6.000
# 15217  Renault Espace    Transporter       Automatic  6.000
# 15218  Renault Espace  Station wagon       Automatic  6.000
# 15219  Renault Espace    Transporter       Automatic  6.000
# 15220  Renault Espace  Station wagon       Automatic  6.000
# 15221  Renault Espace  Station wagon       Automatic  6.000
# 15222  Renault Espace            Van       Automatic  6.000
# 15223  Renault Espace  Station wagon       Automatic  6.000
# 15224  Renault Espace            Van       Automatic  6.000
# 15225  Renault Espace            Van       Automatic  6.000
# 15226  Renault Espace            Van       Automatic  6.000
# 15227  Renault Espace            Van       Automatic  6.000
# 15228  Renault Espace            Van       Automatic  6.000
# 15229  Renault Espace  Station wagon       Automatic  6.000
# 15230  Renault Espace    Transporter       Automatic  6.000
# 15231  Renault Espace            Van       Automatic  6.000
# 15232  Renault Espace            Van       Automatic  6.000
# 15233  Renault Espace  Station wagon       Automatic  6.000
# 15234  Renault Espace  Station wagon       Automatic  6.000
# 15235  Renault Espace  Station wagon       Automatic  6.000
# 15236  Renault Espace  Station wagon       Automatic  6.000
# 15237  Renault Espace  Station wagon       Automatic  6.000
# 15238  Renault Espace  Station wagon       Automatic  6.000
# 15239  Renault Espace  Station wagon       Automatic  6.000
# 15240  Renault Espace  Station wagon       Automatic  6.000
# 15241  Renault Espace    Transporter       Automatic  6.000
# 15242  Renault Espace  Station wagon       Automatic  6.000
# 15243  Renault Espace  Station wagon       Automatic  6.000
# 15244  Renault Espace  Station wagon       Automatic  6.000
# 15245  Renault Espace            Van       Automatic  6.000
# 15246  Renault Espace    Transporter       Automatic  6.000
# 15247  Renault Espace  Station wagon       Automatic  6.000
# 15248  Renault Espace  Station wagon       Automatic  6.000
# 15249  Renault Espace            Van       Automatic  6.000
# 15250  Renault Espace            Van       Automatic  6.000
# 15251  Renault Espace            Van       Automatic  6.000
# 15252  Renault Espace  Station wagon       Automatic  6.000
# 15253  Renault Espace            Van       Automatic  6.000
# 15254  Renault Espace            Van       Automatic  6.000
# 15255  Renault Espace            Van       Automatic  6.000
# 15256  Renault Espace  Station wagon       Automatic  7.000
# 15257  Renault Espace            Van       Automatic  6.000
# 15258  Renault Espace            Van       Automatic  6.000
# 15259  Renault Espace            Van       Automatic  6.000
# 15260  Renault Espace            Van       Automatic  6.000
# 15261  Renault Espace            Van       Automatic  6.000
# 15262  Renault Espace            Van       Automatic  6.000
# 15263  Renault Espace            Van       Automatic  6.000
# 15264  Renault Espace            Van       Automatic  6.000
# 15265  Renault Espace            Van       Automatic  6.000
# 15266  Renault Espace            Van       Automatic  6.000
# 15267  Renault Espace            Van       Automatic  6.000
# 15268  Renault Espace  Station wagon       Automatic  6.000
# 15269  Renault Espace            Van       Automatic  6.000
# 15270  Renault Espace            Van       Automatic  6.000
# 15271  Renault Espace  Station wagon       Automatic  6.000
# 15272  Renault Espace            Van       Automatic  6.000
# 15273  Renault Espace  Station wagon       Automatic  6.000
# 15274  Renault Espace        Compact       Automatic  7.000
# 15275  Renault Espace            Van       Automatic  6.000
# 15276  Renault Espace            Van       Automatic  6.000
# 15277  Renault Espace            Van       Automatic  6.000
# 15278  Renault Espace            Van       Automatic  6.000
# 15279  Renault Espace  Station wagon       Automatic  6.000
# 15280  Renault Espace            Van       Automatic  6.000
# 15281  Renault Espace    Transporter       Automatic  6.000
# 15282  Renault Espace            Van       Automatic  6.000
# 15283  Renault Espace            Van       Automatic  6.000
# 15284  Renault Espace       Off-Road       Automatic  6.000
# 15285  Renault Espace            Van          Manual  6.000
# 15286  Renault Espace            Van          Manual  6.000
# 15287  Renault Espace            Van          Manual  6.000
# 15288  Renault Espace    Transporter          Manual  6.000
# 15289  Renault Espace            Van          Manual  6.000
# 15290  Renault Espace            Van          Manual  6.000
# 15291  Renault Espace            Van          Manual  6.000
# 15292  Renault Espace            Van          Manual  6.000
# 15293  Renault Espace  Station wagon          Manual  6.000
# 15294  Renault Espace    Transporter          Manual  6.000
# 15295  Renault Espace  Station wagon          Manual  6.000
# 15296  Renault Espace  Station wagon          Manual  6.000
# 15297  Renault Espace            Van          Manual  6.000
# 15298  Renault Espace            Van          Manual  6.000
# 15299  Renault Espace         Sedans          Manual  6.000
# 15300  Renault Espace            Van          Manual  6.000
# 15301  Renault Espace            Van          Manual  6.000
# 15302  Renault Espace            Van          Manual  6.000
# 15303  Renault Espace            Van          Manual  6.000
# 15304  Renault Espace            Van          Manual  6.000
# 15305  Renault Espace            Van          Manual  7.000
# 15306  Renault Espace            Van          Manual  6.000
# 15307  Renault Espace            Van          Manual  6.000
# 15308  Renault Espace  Station wagon          Manual  7.000
# 15309  Renault Espace            Van          Manual  6.000
# 15310  Renault Espace            Van          Manual  6.000
# 15311  Renault Espace            Van          Manual  6.000
# 15312  Renault Espace            Van          Manual  6.000
# 15313  Renault Espace            Van          Manual  6.000
# 15314  Renault Espace            Van          Manual  6.000
# 15315  Renault Espace            Van          Manual  6.000
# 15316  Renault Espace            Van          Manual  6.000
# 15317  Renault Espace    Transporter          Manual  6.000
# 15318  Renault Espace            Van          Manual  6.000
# 15887  Renault Espace  Station wagon       Automatic  7.000
# 15888  Renault Espace            Van       Automatic  7.000
# 15889  Renault Espace  Station wagon       Automatic  7.000
# 15890  Renault Espace  Station wagon       Automatic  6.000
# 15891  Renault Espace            Van       Automatic  6.000
# 15892  Renault Espace            Van       Automatic  6.000
# 15893  Renault Espace            Van       Automatic  6.000
# 15894  Renault Espace            Van       Automatic  6.000
# 15895  Renault Espace  Station wagon       Automatic  6.000
# 15896  Renault Espace            Van       Automatic  6.000
# 15897  Renault Espace            Van       Automatic  7.000
# 15898  Renault Espace            Van       Automatic  6.000
# 15899  Renault Espace            Van       Automatic  6.000
# 15900  Renault Espace            Van       Automatic  6.000
# 15901  Renault Espace            Van       Automatic  6.000
# 15902  Renault Espace         Sedans       Automatic  6.000
# 15903  Renault Espace            Van       Automatic  6.000
# 15904  Renault Espace  Station wagon       Automatic  6.000
# 15905  Renault Espace        Compact       Automatic  6.000
# 15906  Renault Espace            Van       Automatic  6.000
# 15907  Renault Espace            Van       Automatic  7.000
# 15908  Renault Espace            Van       Automatic  6.000
# 15909  Renault Espace            Van       Automatic  7.000
# 15910  Renault Espace            Van       Automatic  7.000
# 15911  Renault Espace            Van       Automatic  6.000
# 15912  Renault Espace            Van       Automatic  6.000
# 15913  Renault Espace            Van       Automatic  6.000
# 15914  Renault Espace            Van       Automatic  6.000
# 15915  Renault Espace            Van       Automatic  7.000
# 15916  Renault Espace            Van       Automatic  6.000
# 15917  Renault Espace            Van       Automatic  6.000
# 15918  Renault Espace            Van       Automatic  6.000

# %% [markdown]
# **Is it possible that there have been modern cars with manual/automatic transmissions with 1, 2, 3, 4, 9, 50 gears?**
#
# Most modern cars with manual transmissions have 5 or 6 forward gears. Most modern cars with automatic transmissions have 5–8 forward gears. A few have as many as 10 [Source](https://www.quora.com/What-are-maximum-number-of-transmission-gears).
# Contemporary manual transmissions for cars typically use five or six forward gears ratios and one reverse gear, however, transmissions with between two and seven gears have been produced at times [Source](https://en.wikipedia.org/wiki/Manual_transmission).

# %%
df["Gears"].replace([1, 2, 3, 4, 9, 50], np.nan, inplace=True)

# %%
df.Gears.isnull().sum()
# Out:
# 14

# %%
fill(df, "make_model", "body_type", "Gears", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 6.000    8625
# 5.000    4259
# 7.000    2810
# 8.000     225
# Name: Gears, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.Gears, bins=50)

plt.subplot(122)
plt.boxplot(df.Gears, whis=1.5)

plt.show()

# %% [markdown]
# ## displacement_cc

# %%
first_looking("Displacement_cc")
# Out:
# column name    :  Displacement_cc
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  77
# --------------------------------
# 1598.000     5044
# 999.000      2467
# 1398.000     1387
# 1399.000      768
# 1229.000      678
# 1956.000      670
# 1461.000      667
# 1490.000      559
# 1422.000      467
# 1197.000      372
# 898.000       351
# 1395.000      320
# 1968.000      301
# 1149.000      288
# 1618.000      212
# 1798.000      210
# 1498.000      196
# 1600.000      130
# 1248.000      110
# 1997.000      103
# 1364.000      102
# 1400.000       90
# 998.000        72
# 1500.000       50
# 2000.000       46
# 1000.000       40
# 1.000          36
# 1998.000       25
# 2480.000       20
# 1200.000       18
# 1984.000       18
# 1397.000       11
# 899.000        11
# 160.000         6
# 929.000         5
# 1499.000        5
# 997.000         4
# 1596.000        4
# 139.000         4
# 900.000         4
# 1599.000        3
# 1199.000        3
# 1396.000        3
# 1495.000        2
# 1589.000        2
# 1300.000        2
# 2.000           2
# 995.000         2
# 1496.000        1
# 890.000         1
# 1580.000        1
# 1995.000        1
# 1333.000        1
# 54.000          1
# 1533.000        1
# 1100.000        1
# 1350.000        1
# 16000.000       1
# 1856.000        1
# 1568.000        1
# 1896.000        1
# 1584.000        1
# 996.000         1
# 1696.000        1
# 1686.000        1
# 15898.000       1
# 1368.000        1
# 140.000         1
# 973.000         1
# 1239.000        1
# 1369.000        1
# 1390.000        1
# 122.000         1
# 1198.000        1
# 1195.000        1
# 2967.000        1
# 1800.000        1
# Name: Displacement_cc, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.Displacement_cc, bins=50)

plt.subplot(122)
plt.boxplot(df.Displacement_cc, whis=2.5)

plt.show()

# %%
df.Displacement_cc.describe()
# Out:
# count   15919.000
# mean     1425.609
# std       329.720
# min         1.000
# 25%      1229.000
# 50%      1461.000
# 75%      1598.000
# max     16000.000
# Name: Displacement_cc, dtype: float64

# %%
df.sort_values(by=["Displacement_cc"], ascending=False)["Displacement_cc"].head(5)
# Out:
# 10932   16000.000
# 7169    15898.000
# 10771    2967.000
# 3595     2480.000
# 3587     2480.000
# Name: Displacement_cc, dtype: float64

# %%
df.sort_values(by=["Displacement_cc"], ascending=True)["Displacement_cc"].head(55)
# Out:
# 12790     1.000
# 14319     1.000
# 14315     1.000
# 12849     1.000
# 12848     1.000
# 12835     1.000
# 12823     1.000
# 12815     1.000
# 12800     1.000
# 12798     1.000
# 12796     1.000
# 12786     1.000
# 12783     1.000
# 12781     1.000
# 12769     1.000
# 12768     1.000
# 12750     1.000
# 12670     1.000
# 12604     1.000
# 12554     1.000
# 12501     1.000
# 12499     1.000
# 12484     1.000
# 12473     1.000
# 12467     1.000
# 14284     1.000
# 14320     1.000
# 14321     1.000
# 14314     1.000
# 14322     1.000
# 14328     1.000
# 14327     1.000
# 13904     1.000
# 14325     1.000
# 14326     1.000
# 14324     1.000
# 10559     2.000
# 14198     2.000
# 13912    54.000
# 10194   122.000
# 7810    139.000
# 7812    139.000
# 7811    139.000
# 7809    139.000
# 8128    140.000
# 15578   160.000
# 15576   160.000
# 15574   160.000
# 15575   160.000
# 15577   160.000
# 15579   160.000
# 13653   890.000
# 14694   898.000
# 14342   898.000
# 14695   898.000
# Name: Displacement_cc, dtype: float64

# %%
outlier_bool_list = df.Displacement_cc.isin([1, 2, 54, 122, 139, 140, 160, 16000, 15898])

# %%
outlier_bool_list
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15914    False
# 15915    False
# 15916    False
# 15917    False
# 15918    False
# Name: Displacement_cc, Length: 15919, dtype: bool

# %%
df.loc[outlier_bool_list, "Displacement_cc"] = np.nan

# %%
df.Displacement_cc.isnull().sum()
# Out:
# 53

# %%
fill(df, "make_model", "body_type", "Displacement_cc", "mode")
# Out:
# Number of NaN :  0
# ------------------
#


# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.Weight_kg, bins=15)

plt.subplot(122)
plt.boxplot(df.Weight_kg, whis=2.5)

plt.show()

# %%
df.Weight_kg.describe()
# Out:
# count   15919.000
# mean     1337.432
# std       200.466
# min         1.000
# 25%      1165.000
# 50%      1295.000
# 75%      1472.000
# max      2471.000
# Name: Weight_kg, dtype: float64

# %%
df["Weight_kg"].sort_values().head(10)
# Out:
# 8355      1.000
# 12779     1.000
# 1143    102.000
# 8857    840.000
# 14313   900.000
# 13513   977.000
# 13555   977.000
# 14654   980.000
# 14105   980.000
# 13999   980.000
# Name: Weight_kg, dtype: float64

# %%
df["Weight_kg"].replace([1, 102], np.nan, inplace = True)

# %%
df["Weight_kg"].isnull().sum()
# Out:
# 3

# %%
fill(df, "make_model", "body_type", "Weight_kg", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 1163.000    1583
# 1360.000    1419
# 1487.000     967
# 1135.000     837
# 1425.000     744
# 1180.000     695
# 1273.000     656
# 1165.000     603
# 1503.000     561
# 1734.000     556
# 1087.000     291
# 1335.000     242
# 1365.000     211
# 1199.000     205
# 1350.000     156
# 1119.000     153
# 1355.000     136
# 1280.000     127
# 1260.000     127
# 1275.000     112
# 1278.000     110
# 1255.000     108
# 1200.000     107
# 1522.000     103
# 1659.000     102
# 1195.000      96
# 1120.000      93
# 1403.000      91
# 1701.000      87
# 1250.000      85
# 1685.000      83
# 1441.000      82
# 1308.000      80
# 1285.000      80
# 1613.000      75
# 1110.000      75
# 1279.000      72
# 1364.000      70
# 1345.000      67
# 1733.000      65
# 1071.000      64
# 1141.000      64
# 1209.000      64
# 1325.000      64
# 1230.000      63
# 1845.000      56
# 1090.000      54
# 1052.000      53
# 1154.000      52
# 1664.000      52
# 1513.000      51
# 1065.000      50
# 1237.000      49
# 1440.000      46
# 1205.000      46
# 1088.000      46
# 1265.000      45
# 1395.000      44
# 1666.000      43
# 1585.000      43
# 1134.000      42
# 1162.000      42
# 1248.000      40
# 1393.000      40
# 1288.000      40
# 1092.000      38
# 1472.000      38
# 1263.000      36
# 1552.000      36
# 1456.000      35
# 1415.000      35
# 1820.000      35
# 1146.000      33
# 1615.000      33
# 1623.000      32
# 1840.000      32
# 1228.000      31
# 1680.000      31
# 1328.000      31
# 1633.000      29
# 1215.000      29
# 1322.000      29
# 1385.000      28
# 1063.000      27
# 1315.000      27
# 1155.000      27
# 1571.000      27
# 1276.000      27
# 1743.000      27
# 1059.000      26
# 1220.000      25
# 1580.000      25
# 1660.000      24
# 1105.000      22
# 1790.000      22
# 1695.000      21
# 1173.000      21
# 1388.000      20
# 1170.000      20
# 1635.000      20
# 1300.000      20
# 1582.000      19
# 1198.000      19
# 1370.000      19
# 1890.000      19
# 1225.000      19
# 1310.000      18
# 1537.000      18
# 1655.000      17
# 1400.000      16
# 1843.000      16
# 1540.000      16
# 1518.000      16
# 1055.000      15
# 1235.000      15
# 1380.000      15
# 2353.000      15
# 1760.000      15
# 1596.000      14
# 1305.000      14
# 1510.000      14
# 1708.000      14
# 1640.000      14
# 1079.000      13
# 1758.000      13
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  80
# --------------------------------
# 85.000     2543
# 66.000     2124
# 81.000     1403
# 100.000    1314
# 110.000    1113
# 70.000      890
# 125.000     711
# 51.000      696
# 55.000      589
# 118.000     550
# 92.000      466
# 121.000     392
# 147.000     380
# 77.000      353
# 56.000      294
# 54.000      276
# 103.000     253
# 87.000      232
# 165.000     194
# 88.000      177
# 60.000      160
# 162.000      98
# 74.000       81
# 96.000       72
# 71.000       59
# 101.000      47
# 67.000       40
# 154.000      39
# 122.000      35
# 119.000      30
# 164.000      27
# 135.000      24
# 52.000       22
# 82.000       22
# 1.000        20
# 78.000       20
# 294.000      18
# 146.000      18
# 141.000      16
# 57.000       10
# 120.000       8
# 104.000       8
# 112.000       7
# 191.000       7
# 155.000       6
# 117.000       6
# 184.000       5
# 65.000        4
# 90.000        4
# 76.000        4
# 168.000       3
# 98.000        3
# 149.000       3
# 80.000        3
# 93.000        3
# 167.000       2
# 228.000       2
# 53.000        2
# 143.000       2
# 150.000       2
# 140.000       2
# 270.000       2
# 63.000        2
# 40.000        2
# 127.000       2
# 86.000        2
# 89.000        2
# 163.000       1
# 132.000       1
# 115.000       1
# 239.000       1
# 4.000         1
# 137.000       1
# 133.000       1
# 84.000        1
# 123.000       1
# 44.000        1
# 195.000       1
# 75.000        1
# 9.000         1
# Name: hp_kW, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.hp_kW, bins=15)

plt.subplot(122)
plt.boxplot(df.hp_kW, whis=2.5)

plt.show()

# %%
df.hp_kW.describe()
# Out:
# count   15919.000
# mean       88.374
# std        26.844
# min         1.000
# 25%        66.000
# 50%        85.000
# 75%       101.000
# max       294.000
# Name: hp_kW, dtype: float64

# %%
df.hp_kW.sort_values().head(50)
# Out:
# 6034     1.000
# 6946     1.000
# 7014     1.000
# 9285     1.000
# 9287     1.000
# 6005     1.000
# 9288     1.000
# 7018     1.000
# 9289     1.000
# 9290     1.000
# 9292     1.000
# 9299     1.000
# 10610    1.000
# 10580    1.000
# 10579    1.000
# 10468    1.000
# 15155    1.000
# 15156    1.000
# 7019     1.000
# 7016     1.000
# 13885    4.000
# 3913     9.000
# 8857    40.000
# 13759   40.000
# 8408    44.000
# 10282   51.000
# 10283   51.000
# 10284   51.000
# 10285   51.000
# 10286   51.000
# 10287   51.000
# 9145    51.000
# 10288   51.000
# 10346   51.000
# 10281   51.000
# 10330   51.000
# 9026    51.000
# 9025    51.000
# 10342   51.000
# 10289   51.000
# 9159    51.000
# 9384    51.000
# 9158    51.000
# 10290   51.000
# 10291   51.000
# 10345   51.000
# 10280   51.000
# 10279   51.000
# 10278   51.000
# 10264   51.000
# Name: hp_kW, dtype: float64

# %%
np.sort(df.hp_kW.unique())
# Out:
# array([  1.,   4.,   9.,  40.,  44.,  51.,  52.,  53.,  54.,  55.,  56.,
#         57.,  60.,  63.,  65.,  66.,  67.,  70.,  71.,  74.,  75.,  76.,
#         77.,  78.,  80.,  81.,  82.,  84.,  85.,  86.,  87.,  88.,  89.,
#         90.,  92.,  93.,  96.,  98., 100., 101., 103., 104., 110., 112.,
#        115., 117., 118., 119., 120., 121., 122., 123., 125., 127., 132.,
#        133., 135., 137., 140., 141., 143., 146., 147., 149., 150., 154.,
#        155., 162., 163., 164., 165., 167., 168., 184., 191., 195., 228.,
#        239., 270., 294.])

# %%
df.hp_kW.loc[df.hp_kW < 40] = np.nan

# %%
df.hp_kW.isnull().sum()
# Out:
# 22

# %%
fill(df, "make_model", "body_type", "hp_kW", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 85.000     2544
# 66.000     2124
# 81.000     1403
# 100.000    1317
# 110.000    1117
# 70.000      890
# 125.000     715
# 51.000      703
# 55.000      589
# 118.000     552
# 92.000      466
# 121.000     392
# 147.000     380
# 77.000      353
# 56.000      295
# 54.000      276
# 103.000     253
# 87.000      232
# 165.000     194
# 88.000      177
# 60.000      160
# 162.000      98
# 74.000       81
# 96.000       72
# 71.000       59
# 101.000      47
# 67.000       40
# 154.000      39
# 122.000      35
# 119.000      30
# 164.000      27
# 135.000      24
# 52.000       22
# 82.000       22
# 78.000       20
# 294.000      18
# 146.000      18
# 141.000      16
# 57.000       10
# 120.000       8
# 104.000       8
# 112.000       7
# 191.000       7
# 155.000       6
# 117.000       6
# 184.000       5
# 65.000        4
# 76.000        4
# 90.000        4
# 98.000        3
# 168.000       3
# 149.000       3
# 80.000        3
# 93.000        3
# 143.000       2
# 86.000        2
# 140.000       2
# 150.000       2
# 228.000       2
# 270.000       2
# 53.000        2
# 167.000       2
# 63.000        2
# 40.000        2
# 127.000       2
# 89.000        2
# 123.000       1
# 84.000        1
# 239.000       1
# 44.000        1
# 137.000       1
# 163.000       1
# 75.000        1
# 132.000       1
# 115.000       1
# 195.000       1
# 133.000       1
# Name: hp_kW, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.hp_kW, bins=15)

plt.subplot(122)
plt.boxplot(df.hp_kW, whis=2.5)

plt.show()

# %% [markdown]
# ## CO2_Emission

# %%
first_looking("CO2_Emission")
# Out:
# column name    :  CO2_Emission
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  124
# --------------------------------
# 120.000      1000
# 104.000       782
# 97.000        631
# 99.000        593
# 124.000       574
# 102.000       501
# 85.000        456
# 103.000       445
# 128.000       425
# 106.000       418
# 105.000       401
# 117.000       394
# 114.000       390
# 119.000       381
# 107.000       379
# 137.000       376
# 108.000       362
# 129.000       356
# 126.000       353
# 118.000       270
# 110.000       266
# 127.000       257
# 135.000       252
# 113.000       237
# 111.000       237
# 109.000       234
# 139.000       224
# 140.000       218
# 141.000       214
# 92.000        198
# 123.000       189
# 130.000       180
# 150.000       174
# 112.000       171
# 143.000       171
# 95.000        161
# 116.000       157
# 98.000        156
# 131.000       151
# 153.000       149
# 101.000       147
# 136.000       145
# 133.000       145
# 125.000       133
# 134.000       130
# 145.000       126
# 149.000       117
# 147.000       109
# 132.000       100
# 115.000        86
# 122.000        84
# 121.000        82
# 138.000        75
# 93.000         66
# 142.000        58
# 168.000        58
# 100.000        55
# 148.000        48
# 94.000         42
# 144.000        40
# 154.000        40
# 146.000        36
# 90.000         35
# 151.000        34
# 91.000         31
# 186.000        31
# 152.000        28
# 187.000        26
# 82.000         25
# 172.000        25
# 96.000         22
# 89.000         19
# 189.000        19
# 157.000        18
# 158.000        17
# 88.000         15
# 169.000        15
# 156.000        14
# 164.000        13
# 170.000        10
# 161.000        10
# 166.000         8
# 155.000         8
# 175.000         8
# 188.000         7
# 159.000         7
# 174.000         6
# 87.000          6
# 36.000          5
# 197.000         4
# 166.500         3
# 12087.000       3
# 5.000           3
# 194.000         3
# 167.000         2
# 162.000         2
# 0.000           2
# 191.000         2
# 84.000          2
# 199.000         2
# 183.000         1
# 171.000         1
# 45.000          1
# 331.000         1
# 13983.000       1
# 1.000           1
# 180.000         1
# 177.000         1
# 181.000         1
# 134.500         1
# 14457.000       1
# 12324.000       1
# 184.000         1
# 1060.000        1
# 239.000         1
# 990.000         1
# 190.000         1
# 253.000         1
# 160.000         1
# 80.000          1
# 14.000          1
# 51.000          1
# 165.000         1
# 193.000         1
# Name: CO2_Emission, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.CO2_Emission, bins=100)

plt.subplot(122)
plt.boxplot(df.CO2_Emission, whis=2.5)

plt.show()

# %%
df.CO2_Emission.describe()
# Out:
# count   15919.000
# mean      122.619
# std       248.534
# min         0.000
# 25%       104.000
# 50%       117.000
# 75%       129.000
# max     14457.000
# Name: CO2_Emission, dtype: float64

# %%
df.CO2_Emission.value_counts().sort_index()
# Out:
# 0.000           2
# 1.000           1
# 5.000           3
# 14.000          1
# 36.000          5
# 45.000          1
# 51.000          1
# 80.000          1
# 82.000         25
# 84.000          2
# 85.000        456
# 87.000          6
# 88.000         15
# 89.000         19
# 90.000         35
# 91.000         31
# 92.000        198
# 93.000         66
# 94.000         42
# 95.000        161
# 96.000         22
# 97.000        631
# 98.000        156
# 99.000        593
# 100.000        55
# 101.000       147
# 102.000       501
# 103.000       445
# 104.000       782
# 105.000       401
# 106.000       418
# 107.000       379
# 108.000       362
# 109.000       234
# 110.000       266
# 111.000       237
# 112.000       171
# 113.000       237
# 114.000       390
# 115.000        86
# 116.000       157
# 117.000       394
# 118.000       270
# 119.000       381
# 120.000      1000
# 121.000        82
# 122.000        84
# 123.000       189
# 124.000       574
# 125.000       133
# 126.000       353
# 127.000       257
# 128.000       425
# 129.000       356
# 130.000       180
# 131.000       151
# 132.000       100
# 133.000       145
# 134.000       130
# 134.500         1
# 135.000       252
# 136.000       145
# 137.000       376
# 138.000        75
# 139.000       224
# 140.000       218
# 141.000       214
# 142.000        58
# 143.000       171
# 144.000        40
# 145.000       126
# 146.000        36
# 147.000       109
# 148.000        48
# 149.000       117
# 150.000       174
# 151.000        34
# 152.000        28
# 153.000       149
# 154.000        40
# 155.000         8
# 156.000        14
# 157.000        18
# 158.000        17
# 159.000         7
# 160.000         1
# 161.000        10
# 162.000         2
# 164.000        13
# 165.000         1
# 166.000         8
# 166.500         3
# 167.000         2
# 168.000        58
# 169.000        15
# 170.000        10
# 171.000         1
# 172.000        25
# 174.000         6
# 175.000         8
# 177.000         1
# 180.000         1
# 181.000         1
# 183.000         1
# 184.000         1
# 186.000        31
# 187.000        26
# 188.000         7
# 189.000        19
# 190.000         1
# 191.000         2
# 193.000         1
# 194.000         3
# 197.000         4
# 199.000         2
# 239.000         1
# 253.000         1
# 331.000         1
# 990.000         1
# 1060.000        1
# 12087.000       3
# 12324.000       1
# 13983.000       1
# 14457.000       1
# Name: CO2_Emission, dtype: int64

# %%
df.groupby(["make_model", "body_type", "CO2_Emission"]).price.describe()
# Out:
#                                             count      mean       std  \
# make_model     body_type     CO2_Emission
#                              134.000       7999.000  7999.000
#                              135.000       9389.000  9999.000
#                              140.000      13990.000 13990.000
#                Transporter   85.000        9065.000 10798.000
#                              95.000        7000.000  7000.000
#                              118.000       9262.000  9262.000
#                              128.000      10316.250 10460.000
#                Van           114.000       9775.000  9900.000
# Renault Duster Off-Road      1.000        10850.000 10850.000
#                              150.000      16033.000 16033.000
#                              186.000      14399.000 14823.000
# Renault Espace Compact       120.000      35875.000 43000.000
#                              140.000      17900.000 17900.000
#                              153.000      39990.000 39990.000
#                Coupe         120.000      32353.500 34140.000
#                Off-Road      120.000      28675.000 32900.000
#                              123.000      24900.000 24900.000
#                Sedans        116.000      23990.000 23990.000
#                              123.000      29728.750 32800.000
#                              139.000      46634.250 48498.000
#                              153.000      33195.000 36900.000
#                              172.000      46895.000 46895.000
#                Station wagon 116.000      18835.000 21490.000
#                              120.000      23470.000 39990.000
#                              123.000      29996.750 37990.000
#                              135.000      41390.000 41390.000
#                              139.000      47365.000 52990.000
#                              140.000      26740.000 33900.000
#                              153.000      35062.500 43790.000
#                              168.000      42882.500 50950.000
#                Transporter   116.000      20500.000 27999.000
#                              120.000      26000.000 31000.000
#                              135.000      32700.000 32700.000
#                              140.000      24400.000 24400.000
#                Van           116.000      24900.000 31800.000
#                              117.000      19990.000 19990.000
#                              119.000      24992.500 26990.000
#                              120.000      31965.000 68320.000
#                              122.000      32000.000 32000.000
#                              123.000      34982.500 47450.000
#                              125.000      32395.000 46890.000
#                              135.000      35482.500 46760.000
#                              139.000      45990.000 54205.000
#                              140.000      30285.000 45990.000
#                              142.000      43740.000 45890.000
#                              147.000      32570.000 34170.000
#                              148.000      46909.000 50170.000
#                              151.000      48435.000 48720.000
#                              152.000      55088.750 58950.000
#                              153.000      38700.000 64332.000
#                              161.000      36789.500 38690.000
#                              168.000      39937.500 54120.000
#                              172.000      46420.000 48800.000
#                              174.000      54925.000 57990.000
#                              175.000      38286.750 41480.000
#                              188.000      43080.000 43080.000
#                              191.000      28465.000 28465.000
#                              193.000      38990.000 38990.000
#                              194.000      46490.000 46490.000

# %%
cond = ((df.CO2_Emission < 36) | (df.CO2_Emission > 330))

df.loc[cond, "CO2_Emission"] = np.nan

# %%
df.CO2_Emission.isnull().sum()
# Out:
# 16

# %%
fill(df, "make_model", "body_type", "CO2_Emission", "median")
# Out:
# Number of NaN :  0
# ------------------
# 120.000    1000
# 104.000     782
# 97.000      631
# 99.000      593
# 124.000     574
# 102.000     501
# 85.000      456
# 103.000     445
# 128.000     425
# 106.000     420
# 105.000     402
# 117.000     394
# 114.000     390
# 119.000     384
# 107.000     379
# 137.000     376
# 108.000     362
# 129.000     357
# 126.000     353
# 118.000     270
# 110.000     266
# 127.000     257
# 135.000     252
# 113.000     237
# 111.000     237
# 109.000     234
# 139.000     224
# 140.000     218
# 141.000     214
# 92.000      198
# 123.000     189
# 130.000     180
# 150.000     174
# 112.000     171
# 143.000     171
# 95.000      161
# 116.000     157
# 98.000      156
# 131.000     152
# 153.000     149
# 101.000     147
# 136.000     145
# 133.000     145
# 125.000     133
# 134.000     130
# 145.000     126
# 149.000     117
# 147.000     109
# 132.000     100
# 115.000      86
# 122.000      84
# 121.000      82
# 138.000      79
# 93.000       66
# 168.000      58
# 142.000      58
# 100.000      55
# 148.000      48
# 94.000       42
# 154.000      40
# 144.000      40
# 146.000      36
# 90.000       35
# 151.000      34
# 186.000      32
# 91.000       31
# 152.000      28
# 187.000      26
# 82.000       25
# 172.000      25
# 96.000       22
# 189.000      19
# 89.000       19
# 157.000      18
# 158.000      17
# 169.000      15
# 88.000       15
# 156.000      14
# 164.000      13
# 170.000      10
# 161.000      10
# 166.000       8
# 175.000       8
# 155.000       8
# 159.000       7
# 188.000       7
# 87.000        6
# 174.000       6
# 36.000        5
# 197.000       4
# 120.500       3
# 194.000       3
# 166.500       3
# 84.000        2
# 167.000       2
# 199.000       2
# 191.000       2
# 162.000       2
# 180.000       1
# 134.500       1
# 45.000        1
# 171.000       1
# 183.000       1
# 177.000       1
# 165.000       1
# 181.000       1
# 184.000       1
# 239.000       1
# 190.000       1
# 253.000       1
# 51.000        1
# 80.000        1
# 160.000       1
# 193.000       1
# Name: CO2_Emission, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.CO2_Emission, bins=15)

plt.subplot(122)
plt.boxplot(df.CO2_Emission, whis=2.5)

plt.show()

# %%
plt.figure(figsize = (20, 6))

plt.subplot(121)
plt.hist(np.log(df.CO2_Emission), bins=15)

plt.subplot(122)
plt.boxplot(np.log(df.CO2_Emission), whis=2.5)

plt.show()

# %%
plt.figure(figsize = (20, 6))

plt.subplot(121)
plt.hist(winsorize(df.CO2_Emission, (0.001, 0.003)), bins = 15)

plt.subplot(122)
plt.boxplot(winsorize(df.CO2_Emission, (0.001, 0.003)), whis=2.5)

plt.show()

# %% [markdown]
# ## cons_comb

# %%
first_looking("cons_comb")
# Out:
# column name    :  cons_comb
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  63
# --------------------------------
# 5.400    990
# 4.000    905
# 3.900    846
# 4.700    785
# 5.600    781
# 5.100    769
# 3.800    678
# 5.200    666
# 4.400    624
# 4.800    580
# 5.000    553
# 4.600    539
# 4.500    524
# 4.900    495
# 3.300    446
# 3.700    441
# 4.200    436
# 5.900    395
# 5.300    390
# 5.500    383
# 5.700    342
# 4.100    342
# 6.000    331
# 4.300    308
# 3.500    288
# 6.200    260
# 3.600    232
# 6.100    182
# 6.300    181
# 5.800    165
# 6.800    156
# 6.600    148
# 3.400    130
# 5.350    101
# 6.400     75
# 3.000     69
# 7.400     66
# 6.500     43
# 6.700     43
# 7.100     38
# 6.900     27
# 3.200     25
# 3.650     20
# 8.300     20
# 5.150     19
# 7.600     14
# 7.000     10
# 5.850      7
# 3.100      7
# 7.200      6
# 7.800      6
# 8.000      5
# 1.600      5
# 8.600      4
# 3.950      3
# 8.700      3
# 7.900      3
# 7.300      2
# 8.100      2
# 5.450      2
# 4.550      1
# 9.100      1
# 7.500      1
# Name: cons_comb, dtype: int64

# %%
plt.figure(figsize = (20, 6))

plt.subplot(121)
plt.hist(df.cons_comb, bins = 25)

plt.subplot(122)
plt.boxplot(df.cons_comb, whis = 2)

plt.show()

# %%
df.cons_comb.describe()
# Out:
# count   15919.000
# mean        4.823
# std         0.890
# min         1.600
# 25%         4.000
# 50%         4.800
# 75%         5.400
# max         9.100
# Name: cons_comb, dtype: float64

# %%
df.cons_comb.sort_values().head(10)
# Out:
# 3615    1.600
# 13397   1.600
# 3612    1.600
# 3356    1.600
# 3617    1.600
# 8805    3.000
# 13493   3.000
# 6240    3.000
# 6241    3.000
# 13494   3.000
# Name: cons_comb, dtype: float64

# %%
df.cons_comb.sort_values().tail(10)
# Out:
# 10515   8.300
# 3601    8.300
# 10789   8.600
# 12553   8.600
# 12422   8.600
# 12530   8.600
# 12054   8.700
# 10817   8.700
# 12529   8.700
# 10771   9.100
# Name: cons_comb, dtype: float64

# %% [markdown]
# **Considering our domain knowledge, we can conclude that min value of 3 and max value of 9.10 are normal.**

# %% [markdown]
# ## Nr_of_Doors

# %%
first_looking("Nr_of_Doors")
# Out:
# column name    :  Nr_of_Doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# 5.000    11787
# 4.000     3079
# 3.000      832
# 2.000      219
# 1.000        1
# 7.000        1
# Name: Nr_of_Doors, dtype: int64

# %%
df.Nr_of_Doors.replace([1, 7], np.nan, inplace=True)

# %%
df.Nr_of_Doors.isnull().sum()
# Out:
# 2

# %%
fill(df, "make_model", "body_type", "Nr_of_Doors", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    11789
# 4.000     3079
# 3.000      832
# 2.000      219
# Name: Nr_of_Doors, dtype: int64

# %%
fig, ax = plt.subplots()

df.Nr_of_Doors.value_counts(dropna = False).plot.bar()

for container in ax.containers:
    ax.bar_label(container);

# %%
fig, ax = plt.subplots()

df.groupby(["make_model", "Nr_of_Doors"]).Nr_of_Doors.count().plot.bar()

for container in ax.containers:
    ax.bar_label(container);

# %%
df.drop("Nr_of_Doors", axis=1, inplace=True)

# %% [markdown]
# ## Nr_of_Seats

# %%
first_looking("Nr_of_Seats")
# Out:
# column name    :  Nr_of_Seats
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# 5.000    14308
# 4.000     1127
# 7.000      362
# 2.000      119
# 6.000        2
# 3.000        1
# Name: Nr_of_Seats, dtype: int64

# %%
df.Nr_of_Seats.replace([3, 6], np.nan, inplace=True)

# %%
df.Nr_of_Seats.isnull().sum()
# Out:
# 3

# %%
fill(df, "make_model", "body_type", "Nr_of_Seats", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    14311
# 4.000     1127
# 7.000      362
# 2.000      119
# Name: Nr_of_Seats, dtype: int64

# %%
fig, ax = plt.subplots()

df.Nr_of_Seats.value_counts(dropna=False).plot.bar()

for container in ax.containers:
    ax.bar_label(container);

# %%
fig, ax = plt.subplots()

df.groupby(["make_model", "Nr_of_Seats"]).Nr_of_Seats.count().plot.bar()

for container in ax.containers:
    ax.bar_label(container);

# %%
df.drop("Nr_of_Seats", axis=1, inplace=True)

# %% [markdown]
# ## price

# %%
first_looking("price")
# Out:
# column name    :  price
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2956
# --------------------------------
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.price, bins=20)

plt.subplot(122)
plt.boxplot(df.price, whis=3)

plt.show()

# %%
df.price.describe()
# Out:
# count   15919.000
# mean    18019.897
# std      7386.169
# min        13.000
# 25%     12850.000
# 50%     16900.000
# 75%     21900.000
# max     74600.000
# Name: price, dtype: float64

# %%
df.price.sort_values().head(5)
# Out:
# 8594      13
# 8828     120
# 6066     255
# 8829     331
# 8827    4950
# Name: price, dtype: int64

# %%
drop_index = df.price.sort_values().index[:4]
drop_index
# Out:
# Int64Index([8594, 8828, 6066, 8829], dtype='int64')

# %%
df.drop(drop_index, axis=0, inplace=True)

# %%
df.shape
# Out:
# (15915, 23)

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.hist(df.price, bins=20)

plt.subplot(122)
plt.boxplot(df.price, whis=3)

plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x="make_model", y="price", data=df, whis=3)
plt.show()

# %% [markdown]
# ## make_model

# %%
first_looking("make_model")
# Out:
# column name    :  make_model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  9
# --------------------------------
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2525
# Opel Corsa        2216
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
df[df.make_model=="Audi A2"]
# Out:
#      make_model body_type  price        km            Type    Fuel  Gears  \
# 2614    Audi A2  Off-Road  28200 26166.000  Employee's car  Diesel  6.000
#
#             Extras   age  Previous_Owners  hp_kW  Inspection_new Paint_Type  \
# 2614  Alloy wheels 1.000            1.000 85.000               0   Metallic
#
#      Upholstery_type Gearing_Type  Displacement_cc  Weight_kg Drive_chain  \
# 2614           Cloth       Manual         1598.000   1135.000       front
#
#       cons_comb  CO2_Emission Comfort_Convenience_Package  \
# 2614      4.900       117.000                    Standard
#
#      Entertainment_Media_Package Safety_Security_Package
# 2614                        Plus  Safety Premium Package

# %% [markdown]
# The **``Audi A2``** (internally designated Typ 8Z) is a compact MPV-styled supermini car, with a five-door hatchback body style and four or five seats, produced by the German manufacturer Audi **from November 1999 (for the 2000 model year) to August 2005** [Source](https://en.wikipedia.org/wiki/Audi_A2). **So it is impossible to be a 1-year old Audi A2**.

# %%
drop_index = df[df.make_model == "Audi A2"].index
drop_index
# Out:
# Int64Index([2614], dtype='int64')

# %%
df.drop(drop_index, axis=0, inplace=True)

# %%
df.shape
# Out:
# (15914, 23)

# %% [markdown]
# ## Fuel

# %%
first_looking("Fuel")
# Out:
# column name    :  Fuel
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# Benzine     8548
# Diesel      7297
# LPG/CNG       64
# Electric       5
# Name: Fuel, dtype: int64

# %%
df[df.Fuel == "Electric"][["make_model", "body_type", "CO2_Emission", "Gears", "hp_kW", "cons_comb", "price"]]
# Out:
#          make_model body_type  CO2_Emission  Gears   hp_kW  cons_comb  price
# 3356        Audi A3   Compact        36.000  6.000 150.000      1.600  24950
# 3612        Audi A3    Sedans        36.000  6.000 110.000      1.600  38450
# 3615        Audi A3    Sedans        36.000  6.000 110.000      1.600  35899
# 3617        Audi A3    Sedans        36.000  6.000 110.000      1.600  38000
# 13397  Renault Clio    Sedans        36.000  6.000  55.000      1.600   8490

# %% [raw]
#     	make_model	body_type	CO2 Emission	            Gears	hp_kW	Consumption	                            price
# 3356	Audi A3	    Compact	    NaN	                        [\n6\n]	150.00	NaN	                                    24950
# 3612	Audi A3	    Sedans	    [\n36 g CO2/km (comb)\n]	[\n6\n]	110.00	[\n, 1.6 l/100 km (comb), \n, \n, \n]	38450
# 3615	Audi A3	    Sedans	    [\n36 g CO2/km (comb)\n]	[\n6\n]	110.00	[\n, 1.6 l/100 km (comb), \n, \n, \n]	35899
# 3617	Audi A3	    Sedans	    [\n36 g CO2/km (comb)\n]	[\n6\n]	110.00	[\n, 1.6 l/100 km (comb), \n, \n, \n]	38000
# 13397	RenaultClio	Sedans	    [[], [], []]	            NaN	    nan	    NaN	                                    8490

# %%
drop_index = df[df.Fuel == "Electric"].index
drop_index
# Out:
# Int64Index([3356, 3612, 3615, 3617, 13397], dtype='int64')

# %%
df.drop(drop_index, axis=0, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (15909, 23)

# %% [markdown]
# ## Final_Step

# %%
df.head(3).T
# Out:
#                                                                             0  \
# make_model                                                            Audi A1
# body_type                                                              Sedans
# price                                                                   15770
# km                                                                  56013.000
# Type                                                                     Used
# Fuel                                                                   Diesel
# Gears                                                                   7.000
# Extras                       Alloy wheels, Catalytic Converter, Voice Control
# age                                                                     3.000
# Previous_Owners                                                         2.000
# hp_kW                                                                  66.000
# Inspection_new                                                              1
# Paint_Type                                                           Metallic
# Upholstery_type                                                         Cloth
# Gearing_Type                                                        Automatic
# Displacement_cc                                                      1422.000
# Weight_kg                                                            1220.000
# Drive_chain                                                             front
# cons_comb                                                               3.800
# CO2_Emission                                                           99.000
# Comfort_Convenience_Package                                           Premium
# Entertainment_Media_Package                                              Plus
# Safety_Security_Package                                Safety Premium Package
#
#                                                                              1  \
# make_model                                                             Audi A1
# body_type                                                               Sedans
# price                                                                    14500
# km                                                                   80000.000
# Type                                                                      Used
# Fuel                                                                   Benzine
# Gears                                                                    7.000
# Extras                       Alloy wheels, Sport seats, Sport suspension, V...
# age                                                                      2.000
# Previous_Owners                                                          1.000
# hp_kW                                                                  141.000
# Inspection_new                                                               0
# Paint_Type                                                            Metallic
# Upholstery_type                                                          Cloth
# Gearing_Type                                                         Automatic
# Displacement_cc                                                       1798.000
# Weight_kg                                                             1255.000
# Drive_chain                                                              front
# cons_comb                                                                5.600
# CO2_Emission                                                           129.000
# Comfort_Convenience_Package                                           Standard
# Entertainment_Media_Package                                               Plus
# Safety_Security_Package                                 Safety Premium Package
#
#                                                        2
# make_model                                       Audi A1
# body_type                                         Sedans
# price                                              14640
# km                                             83450.000
# Type                                                Used
# Fuel                                              Diesel
# Gears                                              7.000
# Extras                       Alloy wheels, Voice Control
# age                                                3.000
# Previous_Owners                                    1.000
# hp_kW                                             85.000
# Inspection_new                                         0
# Paint_Type                                      Metallic
# Upholstery_type                                    Cloth
# Gearing_Type                                   Automatic
# Displacement_cc                                 1598.000
# Weight_kg                                       1135.000
# Drive_chain                                        front
# cons_comb                                          3.800
# CO2_Emission                                      99.000
# Comfort_Convenience_Package                      Premium
# Entertainment_Media_Package                     Standard
# Safety_Security_Package           Safety Premium Package

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15909 entries, 0 to 15908
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   make_model                   15909 non-null  object
#  1   body_type                    15909 non-null  object
#  2   price                        15909 non-null  int64
#  3   km                           15909 non-null  float64
#  4   Type                         15909 non-null  object
#  5   Fuel                         15909 non-null  object
#  6   Gears                        15909 non-null  float64
#  7   Extras                       15909 non-null  object
#  8   age                          15909 non-null  float64
#  9   Previous_Owners              15909 non-null  float64
#  10  hp_kW                        15909 non-null  float64
#  11  Inspection_new               15909 non-null  int64
#  12  Paint_Type                   15909 non-null  object
#  13  Upholstery_type              15909 non-null  object
#  14  Gearing_Type                 15909 non-null  object
#  15  Displacement_cc              15909 non-null  float64
#  16  Weight_kg                    15909 non-null  float64
#  17  Drive_chain                  15909 non-null  object
#  18  cons_comb                    15909 non-null  float64
#  19  CO2_Emission                 15909 non-null  float64
#  20  Comfort_Convenience_Package  15909 non-null  object
#  21  Entertainment_Media_Package  15909 non-null  object
#  22  Safety_Security_Package      15909 non-null  object
# dtypes: float64(9), int64(2), object(12)
# memory usage: 2.8+ MB

# %%
df_num = df.select_dtypes("number")
df_num
# Out:
#        price        km  Gears   age  Previous_Owners   hp_kW  Inspection_new  \
# 0      15770 56013.000  7.000 3.000            2.000  66.000               1
# 1      14500 80000.000  7.000 2.000            1.000 141.000               0
# 2      14640 83450.000  7.000 3.000            1.000  85.000               0
# 3      14500 73000.000  6.000 3.000            1.000  66.000               0
# 4      16790 16200.000  7.000 3.000            1.000  66.000               1
# ...      ...       ...    ...   ...              ...     ...             ...
# 15904  39950  1647.363  6.000 0.000            1.000 147.000               0
# 15905  39885  9900.000  7.000 0.000            1.000 165.000               0
# 15906  39875    15.000  6.000 0.000            1.000 146.000               1
# 15907  39700    10.000  6.000 0.000            1.000 147.000               0
# 15908  40999  1647.363  6.000 0.000            1.000 165.000               1
#
#        Displacement_cc  Weight_kg  cons_comb  CO2_Emission
# 0             1422.000   1220.000      3.800        99.000
# 1             1798.000   1255.000      5.600       129.000
# 2             1598.000   1135.000      3.800        99.000
# 3             1422.000   1195.000      3.800        99.000
# 4             1422.000   1135.000      4.100       109.000
# ...                ...        ...        ...           ...
# 15904         1997.000   1758.000      5.300       139.000
# 15905         1798.000   1708.000      7.400       168.000
# 15906         1997.000   1734.000      5.300       139.000
# 15907         1997.000   1758.000      5.300       139.000
# 15908         1798.000   1685.000      6.800       153.000
#
# [15909 rows x 11 columns]

# %%
plt.figure(figsize=(16, 12))

sns.heatmap(df_num.corr(), annot=True, cmap="Blues", linewidths=0.2, annot_kws={"size": 16});

# %%
# function for set text color of correlation values in Dataframes

def color_correlation(val):
    """
    Takes a scalar and returns a string with
    the css property in a variety of color scales 
    for different correlations.
    """
    if val >= 0.6 and val < 0.99999 or val <= -0.6 and val > -0.99999:
        color = 'red'
    elif val < 0.6 and val >= 0.3 or val > -0.6 and val <= -0.3:
        color = 'blue'
    elif val == 1:
        color = 'cyan'    
    else:
        color = 'black'
    return 'color: %s' % color
 
df_num.corr().style.applymap(color_correlation)
# Out:
# <style type="text/css">
#   color: black;
# }
# #T_4b4ea_row0_col5, #T_4b4ea_row1_col3, #T_4b4ea_row3_col1, #T_4b4ea_row5_col0, #T_4b4ea_row5_col8, #T_4b4ea_row8_col5, #T_4b4ea_row9_col10, #T_4b4ea_row10_col9 {
#   color: red;
# }
# </style>
# <table id="T_4b4ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b4ea_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_4b4ea_level0_col1" class="col_heading level0 col1" >km</th>
#       <th id="T_4b4ea_level0_col2" class="col_heading level0 col2" >Gears</th>
#       <th id="T_4b4ea_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_4b4ea_level0_col4" class="col_heading level0 col4" >Previous_Owners</th>
#       <th id="T_4b4ea_level0_col5" class="col_heading level0 col5" >hp_kW</th>
#       <th id="T_4b4ea_level0_col6" class="col_heading level0 col6" >Inspection_new</th>
#       <th id="T_4b4ea_level0_col7" class="col_heading level0 col7" >Displacement_cc</th>
#       <th id="T_4b4ea_level0_col8" class="col_heading level0 col8" >Weight_kg</th>
#       <th id="T_4b4ea_level0_col9" class="col_heading level0 col9" >cons_comb</th>
#       <th id="T_4b4ea_level0_col10" class="col_heading level0 col10" >CO2_Emission</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b4ea_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_4b4ea_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4b4ea_row0_col1" class="data row0 col1" >-0.399443</td>
#       <td id="T_4b4ea_row0_col2" class="data row0 col2" >0.530563</td>
#       <td id="T_4b4ea_row0_col3" class="data row0 col3" >-0.473689</td>
#       <td id="T_4b4ea_row0_col4" class="data row0 col4" >-0.144672</td>
#       <td id="T_4b4ea_row0_col5" class="data row0 col5" >0.696532</td>
#       <td id="T_4b4ea_row0_col6" class="data row0 col6" >0.008508</td>
#       <td id="T_4b4ea_row0_col7" class="data row0 col7" >0.282075</td>
#       <td id="T_4b4ea_row0_col8" class="data row0 col8" >0.468264</td>
#       <td id="T_4b4ea_row0_col9" class="data row0 col9" >0.301448</td>
#       <td id="T_4b4ea_row0_col10" class="data row0 col10" >0.347668</td>
#     </tr>
#     <tr>
#       <th id="T_4b4ea_level0_row1" class="row_heading level0 row1" >km</th>
#       <td id="T_4b4ea_row1_col0" class="data row1 col0" >-0.399443</td>
#       <td id="T_4b4ea_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4b4ea_row1_col2" class="data row1 col2" >-0.033087</td>
#       <td id="T_4b4ea_row1_col3" class="data row1 col3" >0.758370</td>
#       <td id="T_4b4ea_row1_col4" class="data row1 col4" >0.157039</td>
#       <td id="T_4b4ea_row1_col5" class="data row1 col5" >0.004170</td>
#       <td id="T_4b4ea_row1_col6" class="data row1 col6" >-0.049485</td>
#       <td id="T_4b4ea_row1_col7" class="data row1 col7" >0.306792</td>
#       <td id="T_4b4ea_row1_col8" class="data row1 col8" >0.147246</td>
#       <td id="T_4b4ea_row1_col9" class="data row1 col9" >-0.345228</td>
#       <td id="T_4b4ea_row1_col10" class="data row1 col10" >-0.227640</td>
#     </tr>
#     <tr>
#       <th id="T_4b4ea_level0_row2" class="row_heading level0 row2" >Gears</th>
#       <td id="T_4b4ea_row2_col0" class="data row2 col0" >0.530563</td>
#       <td id="T_4b4ea_row2_col1" class="data row2 col1" >-0.033087</td>
#       <td id="T_4b4ea_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4b4ea_row2_col3" class="data row2 col3" >-0.064507</td>
#       <td id="T_4b4ea_row2_col4" class="data row2 col4" >-0.036594</td>
#       <td id="T_4b4ea_row2_col5" class="data row2 col5" >0.449680</td>
#       <td id="T_4b4ea_row2_col6" class="data row2 col6" >-0.011026</td>
#       <td id="T_4b4ea_row2_col7" class="data row2 col7" >0.339431</td>
#       <td id="T_4b4ea_row2_col8" class="data row2 col8" >0.334002</td>
#       <td id="T_4b4ea_row2_col9" class="data row2 col9" >0.011357</td>
#       <td id="T_4b4ea_row2_col10" class="data row2 col10" >0.106674</td>
#     </tr>
#     <tr>
#       <th id="T_4b4ea_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_4b4ea_row3_col0" class="data row3 col0" >-0.473689</td>
#       <td id="T_4b4ea_row3_col1" class="data row3 col1" >0.758370</td>
#       <td id="T_4b4ea_row3_col2" class="data row3 col2" >-0.064507</td>
#       <td id="T_4b4ea_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4b4ea_row3_col4" class="data row3 col4" >0.316166</td>
#       <td id="T_4b4ea_row3_col5" class="data row3 col5" >-0.083334</td>
#       <td id="T_4b4ea_row3_col6" class="data row3 col6" >-0.045467</td>
#       <td id="T_4b4ea_row3_col7" class="data row3 col7" >0.215304</td>
#       <td id="T_4b4ea_row3_col8" class="data row3 col8" >0.065081</td>
#       <td id="T_4b4ea_row3_col9" class="data row3 col9" >-0.371941</td>
#       <td id="T_4b4ea_row3_col10" class="data row3 col10" >-0.288236</td>
#     </tr>
#     <tr>
#       <th id="T_4b4ea_level0_row4" class="row_heading level0 row4" >Previous_Owners</th>
#       <td id="T_4b4ea_row4_col0" class="data row4 col0" >-0.144672</td>
#       <td id="T_4b4ea_row4_col1" class="data row4 col1" >0.157039</td>
#       <td id="T_4b4ea_row4_col2" class="data row4 col2" >-0.036594</td>
#       <td id="T_4b4ea_row4_col3" class="data row4 col3" >0.316166</td>
#       <td id="T_4b4ea_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4b4ea_row4_col5" class="data row4 col5" >-0.022535</td>
#       <td id="T_4b4ea_row4_col6" class="data row4 col6" >0.019519</td>
#       <td id="T_4b4ea_row4_col7" class="data row4 col7" >0.027961</td>
#       <td id="T_4b4ea_row4_col8" class="data row4 col8" >0.003460</td>
#       <td id="T_4b4ea_row4_col9" class="data row4 col9" >-0.022799</td>
#       <td id="T_4b4ea_row4_col10" class="data row4 col10" >-0.030866</td>
#     <

# %%
# sns.pairplot(df_num, size=2.5);

# %% [markdown]
# # Some Specific Questions on Analysis

# %% [markdown]
# ### 1. What is the average kilometer of the vehicles according to their body types?

# %%
avg_km = df.groupby(["make_model", "body_type"]).km.mean()
avg_km
# Out:
# make_model      body_type
# Audi A1         Compact         20668.668
#                 Coupe           38650.000
#                 Sedans          22706.169
#                 Station wagon   22421.048
#                 Van              3000.000
# Audi A3         Compact         62481.837
#                 Convertible     20532.875
#                 Coupe           26876.500
#                 Sedans          37194.306
#                 Station wagon   34814.260
# Opel Astra      Compact         28041.784
#                 Coupe           11293.681
#                 Off-Road        12607.000
#                 Sedans          26394.506
#                 Station wagon   46588.099
# Opel Corsa      Compact         19848.416
#                 Coupe           33260.105
#                 Off-Road        50729.000
#                 Sedans          31992.909
#                 Transporter     52018.623
#                 Van             33633.000
# Opel Insignia   Compact         21232.828
#                 Coupe           28142.000
#                 Off-Road        23670.064
#                 Sedans          29973.055
#                 Station wagon   43170.520
#                 Van             23726.000
# Renault Clio    Compact         21020.925
#                 Coupe           24500.000
#                 Off-Road        47750.000
#                 Sedans          29185.881
#                 Station wagon   39558.021
#                 Transporter     40649.862
#                 Van             29306.500
# Renault Duster  Off-Road          919.663
# Renault Espace  Compact         23831.500
#                 Coupe            7244.000
#                 Off-Road        48669.750
#                 Sedans          24046.761
#                 Station wagon   50438.484
#                 Transporter     61466.212
#                 Van             30395.734
# Name: km, dtype: float64

# %%
ax = avg_km.unstack(level=1).plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=13, rotation=90)
    
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Kilometer', fontsize=30)
plt.legend(title="Make & Model", title_fontsize=14, prop={'size': 14}, bbox_to_anchor=(0.75, 0.55));

# %%
ax = avg_km.unstack(level=0).plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=13, rotation=90)
    
ax.set_xlabel('Body Type', fontsize=30)
ax.set_ylabel('Kilometer', fontsize=30)
plt.legend(title="Make & Model", title_fontsize=14, prop={'size': 14}, bbox_to_anchor=(0.1, 0.6));

# %% [markdown]
# ### 2. What is the average price of the vehicles according to the gear types they use?

# %%
avg_price1 = df.groupby(["make_model", "Gearing_Type"]).price.mean()
avg_price1
# Out:
# make_model      Gearing_Type
# Audi A1         Automatic        21451.658
#                 Manual           16659.505
#                 Semi-automatic   20936.526
# Audi A3         Automatic        21490.719
#                 Manual           19433.989
#                 Semi-automatic   27180.000
# Opel Astra      Automatic        18843.303
#                 Manual           13516.257
#                 Semi-automatic   16132.722
# Opel Corsa      Automatic        14051.363
#                 Manual            9021.493
#                 Semi-automatic   11930.000
# Opel Insignia   Automatic        23114.156
#                 Manual           19747.963
# Renault Clio    Automatic        16238.258
#                 Manual            9502.069
#                 Semi-automatic   16507.756
# Renault Duster  Automatic        14641.500
#                 Manual           12795.923
# Renault Espace  Automatic        30904.995
#                 Manual           23691.402
#                 Semi-automatic   25114.077
# Name: price, dtype: float64

# %%
ax = avg_price1.unstack(level=1).plot.bar(figsize=(20, 8), fontsize=16, width=0.7, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=20, rotation=90)
    
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Gearing Type", title_fontsize=14, prop={'size': 14}, bbox_to_anchor=(0.35, 1));

# %%
ax = avg_price1.unstack(level=0).plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=20, rotation=90)
    
ax.set_xlabel('Gearing Type', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Make & Model", title_fontsize=14, prop={'size': 14}, bbox_to_anchor=(0.4, 0.75));

# %% [markdown]
# ### 3. What is the average price of the vehicles according to the fuel types they use?

# %%
avg_price2 = df.groupby(["make_model", "Fuel"]).price.mean()
avg_price2
# Out:
# make_model      Fuel
# Audi A1         Benzine   20037.974
#                 Diesel    16135.981
# Audi A3         Benzine   22916.431
#                 Diesel    20110.062
#                 LPG/CNG   21684.083
# Opel Astra      Benzine   17816.946
#                 Diesel    13435.740
#                 LPG/CNG   15882.000
# Opel Corsa      Benzine   11313.743
#                 Diesel     7796.086
#                 LPG/CNG    9503.769
# Opel Insignia   Benzine   24890.695
#                 Diesel    19698.871
# Renault Clio    Benzine   13034.561
#                 Diesel    10120.655
#                 LPG/CNG    8545.385
# Renault Duster  Benzine   13230.176
# Renault Espace  Benzine   34814.026
#                 Diesel    28280.308
# Name: price, dtype: float64

# %%
ax = avg_price2.unstack(level=1).plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=20, rotation=90)
    
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Fuel Type", title_fontsize=16, prop={'size': 16}, loc='best');

# %%
ax = avg_price2.unstack(level=0).plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=20, rotation=90)
    
ax.set_xlabel('Fuel Type', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Make & Model", title_fontsize=16, prop={'size': 14}, loc='best');

# %% [markdown]
# ### 4. Which make & model has the highest number of vehicles for sale?

# %%
df["make_model"].value_counts().nlargest(1)
# Out:
# Audi A3    3093
# Name: make_model, dtype: int64

# %%
num_sale = df["make_model"].value_counts()
num_sale
# Out:
# Audi A3           3093
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2525
# Opel Corsa        2216
# Renault Clio      1838
# Renault Espace     991
# Renault Duster      34
# Name: make_model, dtype: int64

# %%
ax = num_sale.plot.bar(figsize=(20, 8), fontsize=16, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=24)
    
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Amount by Number', fontsize=30);

# %% [markdown]
# ### 5. Which vehicle make & models has the lowest fuel consumption by body type and What are their fuel types?

# %%
cons = df.groupby(["make_model", "body_type", "Fuel"]).cons_comb.min()
cons
# Out:
# make_model      body_type      Fuel
# Audi A1         Compact        Benzine   4.000
#                                Diesel    3.000
#                 Coupe          Benzine   4.200
#                                Diesel    4.200
#                 Sedans         Benzine   3.900
#                                Diesel    3.000
#                 Station wagon  Benzine   4.200
#                                Diesel    3.400
#                 Van            Benzine   4.400
# Audi A3         Compact        Benzine   4.500
#                                Diesel    3.000
#                 Convertible    Benzine   4.900
#                                Diesel    3.800
#                 Coupe          Benzine   4.600
#                                Diesel    3.800
#                 Sedans         Benzine   3.500
#                                Diesel    3.000
#                                LPG/CNG   3.300
#                 Station wagon  Benzine   4.400
#                                Diesel    3.300
#                                LPG/CNG   5.300
# Opel Astra      Compact        Benzine   4.000
#                                Diesel    3.000
#                 Coupe          Benzine   5.800
#                 Off-Road       Benzine   5.600
#                 Sedans         Benzine   3.900
#                                Diesel    3.000
#                                LPG/CNG   3.600
#                 Station wagon  Benzine   4.000
#                                Diesel    3.000
# Opel Corsa      Compact        Benzine   3.000
#                                Diesel    3.000
#                                LPG/CNG   5.600
#                 Coupe          Benzine   4.900
#                                Diesel    3.100
#                                LPG/CNG   5.000
#                 Off-Road       Benzine   5.100
#                 Sedans         Benzine   4.200
#                                Diesel    3.100
#                                LPG/CNG   5.300
#                 Transporter    Benzine   5.300
#                                Diesel    3.800
#                 Van            Benzine   5.400
# Opel Insignia   Compact        Benzine   5.300
#                                Diesel    3.900
#                 Coupe          Diesel    5.500
#                 Off-Road       Benzine   5.700
#                                Diesel    6.000
#                 Sedans         Benzine   5.000
#                                Diesel    3.000
#                 Station wagon  Benzine   4.500
#                                Diesel    3.000
#                 Van            Benzine   5.500
# Renault Clio    Compact        Benzine   4.000
#                                Diesel    3.000
#                 Coupe          Benzine   5.900
#                 Off-Road       Benzine   5.500
#                                Diesel    5.500
#                 Sedans         Benzine   4.200
#                                Diesel    3.000
#                                LPG/CNG   6.000
#                 Station wagon  Benzine   4.500
#                                Diesel    3.000
#                 Transporter    Benzine   5.200
#                                Diesel    3.300
#                 Van            Diesel    5.000
# Renault Duster  Off-Road       Benzine   4.800
# Renault Espace  Compact        Benzine   6.200
#                                Diesel    4.700
#                 Coupe          Benzine   4.700
#                                Diesel    4.700
#                 Off-Road       Diesel    4.700
#                 Sedans         Benzine   6.800
#                                Diesel    4.400
#                 Station wagon  Benzine   5.300
#                                Diesel    4.400
#                 Transporter    Benzine   6.200
#                                Diesel    4.500
#                 Van            Benzine   4.700
#                                Diesel    4.000
# Name: cons_comb, dtype: float64

# %%
ax = cons.unstack(level=0).plot.bar(figsize=(20, 8), fontsize=14, width=0.9, rot=60)

for container in ax.containers:
    ax.bar_label(container, fontsize=12, rotation=90)
    
ax.set_xlabel('Body & Fuel Type', fontsize=30)
ax.set_ylabel('Average Consumption', fontsize=30)
plt.legend(title="Make & Model", title_fontsize=12, prop={'size': 10}, bbox_to_anchor=(0.2, 0.7));

# %%
ax = cons.unstack(level=1).plot.bar(figsize=(20, 8), fontsize=14, width=0.9, rot=60)

for container in ax.containers:
    ax.bar_label(container, fontsize=12, rotation=90)
    
ax.set_xlabel('Make-Model & Fuel Type', fontsize=30)
ax.set_ylabel('Average Consumption', fontsize=30)
plt.legend(title="Body Type", title_fontsize=14, prop={'size': 10});

# %%
ax = cons.unstack(level=2).plot.bar(figsize=(20, 8), fontsize=14, width=0.9, rot=90)

for container in ax.containers:
    ax.bar_label(container, fontsize=12, rotation=90)
    
ax.set_xlabel('Make-Model & Body Type', fontsize=30)
ax.set_ylabel('Average Consumption', fontsize=30)
plt.legend(title="Fuel Type", title_fontsize=16, prop={'size': 14});

# %% [markdown]
# ### 6. What are the lowest and highest sales prices of the vehicles according to the make & model? And find the selling price difference for each make & model group. Which vehicle group has the biggest price difference?

# %%
df.groupby(["make_model"]).price.min()
# Out:
# make_model
# Audi A1            8999
# Audi A3            5555
# Opel Astra         6000
# Opel Corsa         4950
# Opel Insignia      8290
# Renault Clio       5445
# Renault Duster    10850
# Renault Espace    12614
# Name: price, dtype: int64

# %%
df.groupby(["make_model"]).price.max()
# Out:
# make_model
# Audi A1           37900
# Audi A3           74600
# Opel Astra        39433
# Opel Corsa        18622
# Opel Insignia     52120
# Renault Clio      31500
# Renault Duster    16033
# Renault Espace    68320
# Name: price, dtype: int64

# %%
min_max_price = df.groupby(["make_model"]).agg({'price': ['max', 'min']}).reset_index()
min_max_price
# Out:
#        make_model  price
#                      max    min
# 0         Audi A1  37900   8999
# 1         Audi A3  74600   5555
# 2      Opel Astra  39433   6000
# 3      Opel Corsa  18622   4950
# 4   Opel Insignia  52120   8290
# 5    Renault Clio  31500   5445
# 6  Renault Duster  16033  10850
# 7  Renault Espace  68320  12614

# %%
ax = min_max_price.plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=15)
    
ax.set_xticklabels(min_max_price.make_model)
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Max & Min Price", title_fontsize=16, prop={'size': 14}, bbox_to_anchor=(0.47, 1));

# %% [markdown]
# **Let us also see the Price differences for each Make & Model in the plot.**

# %%
min_max_price.columns
# Out:
# MultiIndex([('make_model',    ''),
#             (     'price', 'max'),
#             (     'price', 'min')],
#            )

# %%
min_max_price['price', 'difference'] = min_max_price['price', 'max'] - min_max_price['price', 'min']
min_max_price.sort_values(by=('price', 'difference'), ascending=False)
# Out:
#        make_model  price
#                      max    min difference
# 1         Audi A3  74600   5555      69045
# 7  Renault Espace  68320  12614      55706
# 4   Opel Insignia  52120   8290      43830
# 2      Opel Astra  39433   6000      33433
# 0         Audi A1  37900   8999      28901
# 5    Renault Clio  31500   5445      26055
# 3      Opel Corsa  18622   4950      13672
# 6  Renault Duster  16033  10850       5183

# %%
ax = min_max_price.plot.bar(figsize=(20, 8), fontsize=16, width=0.8, rot=0)

for container in ax.containers:
    ax.bar_label(container, fontsize=15)
    
ax.set_xticklabels(min_max_price.make_model)
ax.set_xlabel('Make & Model', fontsize=30)
ax.set_ylabel('Price', fontsize=30)
plt.legend(title="Price Max, Min & Difference", title_fontsize=16, prop={'size': 14});

# %% [markdown]
# ### 7. What is the average selling price of vehicles whose make & model is Opel Corsa and body is sedan?

# %%
df[(df["make_model"] == "Opel Corsa") & (df["body_type"] == "Sedans")].price.mean()

# %% [markdown]
# ### 8. What are the average, minimum and maximum selling prices of vehicles by body type?

# %%
df.groupby(['make_model', 'body_type']).agg({'price': ['mean', 'min', 'max']})

# %% [markdown]
# ### 9. What is the brand of the vehicles whose sales price is between 5000 and 10000 Euros (inclusive)?

# %%
df[(df.price >= 5000) & (df.price <= 10000)]["make_model"].unique()

# %% [markdown]
# ### 10. What is the most common paint type among the vehicles for sale whose make & model is Audi A3 and body is Sedan?

# %%
df[(df["make_model"] == "Audi A3") & (df["body_type"] == "Sedans")].Paint_Type.mode()

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %%
df = pd.read_csv("final_scout_not_dummy.csv")
df.head()

# %% [markdown]
# # Dummy Operations

# %%
df.info()

# %%
df.shape

# %% [markdown]
# ## Aproach 1: Using factorize() method for some categorical features:

# %%
# Encoding the object as an enumerated type or categorical variable.

pd.factorize(df["make_model"])

# %%
df["make_model"].apply(lambda x: pd.factorize(x))

# %%
# Encoding all categorical variable (except for "Extras", , "Comfort_Convenience_Package", "Entertainment_Media_Package", "Safety_Security_Package") in our DataFrame.

df[["make_model_ordinal", "body_type_ordinal", "Type_ordinal", "Fuel_ordinal", "Paint_Type_ordinal", "Upholstery_type_ordinal", "Gearing_Type_ordinal"]] = df[["make_model", "body_type", "Type", "Fuel", "Paint_Type", "Upholstery_type", "Gearing_Type"]].apply(lambda x: pd.factorize(x)[0])
df.head()

# %%
make_model_ordinal = df.pop("make_model_ordinal")
df.insert(1, 'make_model_ordinal', make_model_ordinal)
df.head()

# %% [markdown]
# **Since this is the first time, let us check how factorize() method made changes on the DataFrame:**

# %%
df["make_model"].unique()

# %%
display(df[df["make_model"] == "Audi A1"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Audi A3"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Opel Astra"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Opel Corsa"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Opel Insignia"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Renault Clio"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Renault Duster"][["make_model", "make_model_ordinal"]].sample(5))
display(df[df["make_model"] == "Renault Espace"][["make_model", "make_model_ordinal"]].sample(5))

# %% [markdown]
# **It's time to change the location of all features factorized:**

# %%
df.columns

# %%
# list_of_ordinal_features = ["body_type_ordinal", "Type_ordinal", "Fuel_ordinal", "Paint_Type_ordinal", "Upholstery_type_ordinal", "Gearing_Type_ordinal", "Drive_chain_ordinal", "Comfort_Convenience_Package_ordinal", "Entertainment_Media_Package_ordinal", "Safety_Security_Package_ordinal"]

# pop() method works for a single column and returns a Series
body_type_ordinal = df.pop("body_type_ordinal")
Type_ordinal = df.pop("Type_ordinal")
Fuel_ordinal = df.pop("Fuel_ordinal")
Paint_Type_ordinal = df.pop("Paint_Type_ordinal")
Upholstery_type_ordinal = df.pop("Upholstery_type_ordinal")
Gearing_Type_ordinal = df.pop("Gearing_Type_ordinal")
# Drive_chain_ordinal = df.pop("Drive_chain_ordinal")

# Let's insert the columns we have popped
df.insert(3, "body_type_ordinal", body_type_ordinal)
df.insert(7, "Type_ordinal", Type_ordinal)
df.insert( 9, "Fuel_ordinal", Fuel_ordinal)
df.insert(17, "Paint_Type_ordinal", Paint_Type_ordinal)
df.insert(19, "Upholstery_type_ordinal", Upholstery_type_ordinal)
df.insert(21, "Gearing_Type_ordinal", Gearing_Type_ordinal)
# df.insert(25, "Drive_chain_ordinal", Drive_chain_ordinal)

df.head()

# %% [markdown]
# **Let us drop unnecassary features from our DataFrame.**

# %%
df.columns

# %%
df.drop(['make_model', 'body_type', 'Type', 'Fuel', 'Paint_Type', 'Upholstery_type', 'Gearing_Type'], 
        axis=1, inplace=True)

df.head()

# %%
df.dtypes

# %%
from termcolor import colored

for column in df.columns:
    print(colored("****"*10, "green"))
    print(colored(f"Column Name: {column}", "blue"))
    print(df[column].value_counts(dropna=False))

# %% [markdown]
# ## Aproach 2: Using ``count()`` method for "Extras" feature

# %%
df.Extras.str.count(",").add(1)

# %%
df["Extras"].apply(lambda x: x.count(",")).add(1)

# %%
df["Num_of_Extras"] = df["Extras"].apply(lambda x: x.count(",")).add(1)
df.head()

# %%
df.drop("Extras", axis=1, inplace=True)
df.head().T

# %%
df.dtypes

# %%
## Aproach 2: Using ``count()`` method for "Extras" feature

df.Extras.str.count(",").add(1)

df["Extras"].apply(lambda x: x.count(",")).add(1)

df["Num_of_Extras"] = df["Extras"].apply(lambda x: x.count(",")).add(1)
df.head()

df.drop("Extras", axis=1, inplace=True)
df.head().T

df.dtypes

# %% [markdown]
# ## Aproach 3: Using ``map()`` for 'Drive_chain' feature

# %%
df.info()

# %%
df["Drive_chain"].value_counts()

# %%
df["Drive_chain"] = df["Drive_chain"].map({"rear":0, "4WD":1, "front":2})
df.head()

# %%
df.dtypes

# %% [markdown]
# ## Aproach 4: Using ``cat.codes`` for 'Comfort_Convenience_Package' feature

# %%
df.info()

# %%
df["Comfort_Convenience_Package"].value_counts()

# %%
df["Comfort_Convenience_Package"] = df["Comfort_Convenience_Package"].astype("category")
df.dtypes

# %%
# We can access the codes of the categories by running df["Comfort_Convenience_Package"].cat.codes

df["Comfort_Convenience_Package"] = df["Comfort_Convenience_Package"].cat.codes
df.head()

# %%
df.dtypes

# %% [markdown]
# ## Aproach 5: Using ``LabelEncoder()`` method for 'Safety_Security_Package' & 'Entertainment_Media_Package' features

# %%
for column in df[["Safety_Security_Package", "Entertainment_Media_Package"]]:
    print(colored("****"*10, "green"))
    print(colored(f"Column Name: {column}", "blue"))
    print(df[column].value_counts(dropna=False))

# %% [markdown]
# ### Label Encoding using ``sklearn`` Machine Learning library:

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Creating an instance of LabelEncoder() and storing it in labelencoder variable/object
labelencoder = LabelEncoder()

# Applying LabelEncoder for the columns of "Safety_Security_Package" & "Entertainment_Media_Package"
df[["Safety_Security_Package_Labeled", "Entertainment_Media_Package_Labeled"]] = df[["Safety_Security_Package", "Entertainment_Media_Package"]].apply(labelencoder.fit_transform)
df[["Safety_Security_Package", "Safety_Security_Package_Labeled", "Entertainment_Media_Package", "Entertainment_Media_Package_Labeled"]]

# %%
columns = ["Safety_Security_Package", "Safety_Security_Package_Labeled", "Entertainment_Media_Package", "Entertainment_Media_Package_Labeled"]
for column in columns:
    print(colored("****"*13, "green"))
    print(colored(f"Column Name: {column}", "blue"))
    print(df[column].value_counts(dropna=False))

# %%
display(df[df["Safety_Security_Package"] == "Safety Premium Package"][["Safety_Security_Package", "Safety_Security_Package_Labeled"]].sample(5))
display(df[df["Safety_Security_Package"] == "Safety Premium Plus Package"][["Safety_Security_Package", "Safety_Security_Package_Labeled"]].sample(5))
display(df[df["Safety_Security_Package"] == "Safety Standard Package"][["Safety_Security_Package", "Safety_Security_Package_Labeled"]].sample(5))
display(df[df["Entertainment_Media_Package"] == "Plus"][["Entertainment_Media_Package", "Entertainment_Media_Package_Labeled"]].sample(5))
display(df[df["Entertainment_Media_Package"] == "Standard"][["Entertainment_Media_Package", "Entertainment_Media_Package_Labeled"]].sample(5))

# %% [markdown]
# ### Label Encoding with Python code:

# %%
# !pip install category_encoders

# %%
import category_encoders as ce

# Creating an Object for Label (Ordinal) Encoding
encoder= ce.OrdinalEncoder(cols=['Safety_Security_Package'], return_df=True, 
                           mapping=[{'col':'Safety_Security_Package', 'mapping':{'Safety Standard Package':0, 'Safety Premium Package':1, 'Safety Premium Plus Package':2}}])

# %%
data_encoded_LE = encoder.fit_transform(df["Safety_Security_Package"])
data_encoded_LE

# %%
data_encoded_LE.value_counts(dropna=False)

# %% [markdown]
# ## Aproach 6: Using OneHotEncoder() method for 'Safety_Security_Package' & 'Entertainment_Media_Package' features

# %% [markdown]
# ### One-Hot Encoding using ``sklearn`` Machine Learning library:

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(handle_unknown="ignore", sparse=False)

# %%
data_encoded_LE = pd.DataFrame(encoder.fit_transform(df[["Entertainment_Media_Package"]]))
data_encoded_LE.columns = encoder.get_feature_names(["Entertainment_Media_Package"])
data_encoded_LE = df[["Entertainment_Media_Package"]].join(data_encoded_LE)
data_encoded_LE

# %% [markdown]
# ### One-Hot Encoding with Python code:

# %%
import category_encoders as ce

# Creating an Object for One-Hot Encoding
encoder = ce.OneHotEncoder(cols='Entertainment_Media_Package', handle_unknown='return_nan', return_df=True, use_cat_names=True)

# %%
#Fit and transform Data
data_encoded_OHE = encoder.fit_transform(df['Entertainment_Media_Package'])
data_encoded_OHE

# %% [markdown]
# **Now it's time to drop unnecassary columns.**

# %%
df.head(3)

# %%
df.drop(["Safety_Security_Package", "Entertainment_Media_Package"], axis=1, inplace=True)

# %%
df.head(3)

# %% [markdown]
# **Let us check how our DataFrame looks like after the transformation of categorical features**

# %%
df.info()

# %%
df.shape

# %%
df.to_csv("final_scout_dummy.csv", index=False)

# %%
pd.read_csv("final_scout_dummy.csv")

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of Handling with Outliers (Part - 03)</p>
